# %% [markdown]
# <h1><b>Άσκηση 2</b></h1>
# <p align="justify">Σας δίνεται η παρακάτω στοχαστική μήτρα πιθανοτήτων P μιας μαρκοβιανής αλυσίδας. Από τη μήτρα αυτή έχουν παραλειφθεί ορισμένα στοιχεία:</p>
# <img src="https://raw.githubusercontent.com/nkostopoulos/StochasticsLabPublic/master/2020/lab3/ex2.PNG"><img>
# <ul>
# <li>Να συμπληρώσετε τα κενά της μήτρας πιθανοτήτων P της μαρκοβιανής αλυσίδας.</li>

# %% [markdown]
# ### Απάντηση στο παραπάνω
#
# Γνωρίζουμε πως κάθε γραμμή πρέπει να αθροίζει στο 1. Επομένως το στοιχείο που λείπει κατά γραμμή είναι
#
# __0.2__
#
# __0.6__
#
# __0.0__
#
# __0.6__
#
# __0.0__
#
# __0.2__

# %% [markdown]
# <li>Χρησιμοποιώντας τον <a href="http://setosa.io/markov/index.html#%7B%22tm%22%3A%5B%5B0.6%2C0.2%2C0%2C0%2C0%2C0.2%5D%2C%5B0.2%2C0.6%2C0.2%2C0%2C0%2C0%5D%2C%5B0%2C0.2%2C0.6%2C0.2%2C0%2C0%5D%2C%5B0%2C0%2C0.2%2C0.6%2C0.2%2C0%5D%2C%5B0%2C0%2C0%2C0.2%2C0.6%2C0.2%5D%2C%5B0.2%2C0%2C0%2C0%2C0.2%2C0.6%5D%5D%7D">προσομοιωτή</a> να σχεδιάσετε την παραπάνω μαρκοβιανή αλυσίδα και να ταξινομήσετε τις καταστάσεις της σε κλάσεις επικοινωνίας. Πώς αποκαλείται μια τέτοια αλυσίδα με κριτήριο τις κλάσεις επικοινωνίας; Τι συμπέρασμα βγάζετε σχετικά με την ύπαρξη αναλλοίωτης κατανομής για την αλυσίδα;</li>

# %% [markdown]
# <img src="images/mcex2.png"><img>

# %% [markdown]
# Από τη στιγμή που μπορούμε να πάμε σε όποιον κόμβο θέλουμε, από οποιονδήποτε κόμβο και να είμαστε τότε έχουμε irreducible markov chain.
#
# Καταστάσεις σε κλάσεις επικοινωνίας:
#
# - Αρχικά, όλες με τον εαυτό τους
#
# - C <-> D
# - C <-> B
# - D <-> E
# - C <-> E because C communicates with D and D with E
# - D <-> B because C communicates with B and D with C
# - B <-> A
# - E <-> F
# - A <-> F
# - B <-> F because B communicates with A and A with F
#
# Οπότε έχουμε μια κλάση με όλες τις καταστάσεις {Α,B,C,D,E,F }  εφόσον όλοι μιλάν με όλους. Θα μπορούσε να χαρακτηριστεί κλειστή κλάση εφόσον είναι και μοναδική.

# %% [markdown]
# Eπίσης παρατηρούμε πως η αλυσίδα είναι απεριοδική επομένως αφού ειναι και μη υποβιβάσιμη είναι εργοδική αλυσίδα.Τέλος παρατηρούμε πως η αλυσίδα είναι διπλά στοχαστική αφού και οι στήλες αθροίζουν στο 1. Από αυτό συμπαιρένουμε το εξής για την αναλλοίωτη κατανομή της:
#
# Οι πιθανότητες καταστάσεων π εργοδικής αλυσίδας είναι ανεξάρτητες της αρχικής συνθήκης π(0) και υπολογίζονται μέσω του γραμμικού συστήματος αναλλοίωτης κατανομής εργοδικών πιθανοτήτων.
#
# <img src="images/stationary_dis.png"><img>

# %% [markdown]
# <li>Χρησιμοποιώντας τον κώδικα που παρατίθεται στο τέλος της άσκησης θα εκτιμήσετε την αναλλοίωτη κατανομή της μαρκοβιανής αλυσίδας με τη μέθοδο της προσομοίωσης. Το πρόγραμμα: (α) ορίζει τη μήτρα πιθανοτήτων και την αρχική κατανομή της αλυσίδας, (β) ορίζει το μοντέλο της και (γ) εκτιμά την αναλλοίωτη κατανομή της αλυσίδας για κάθε κατάσταση, διαιρώντας τον αριθμό των επισκέψεων στην κατάσταση αυτή με το συνολικό αριθμό των βημάτων της αλυσίδας (παράμετρος <i>total_runs</i>). Το πρόγραμμα δίνει ως έξοδο ένα ραβδόγραμμα που απεικονίζει την αναλλοίωτη κατανομή της αλυσίδας. Να καταγράψετε το αποτέλεσμα της εκτέλεσης του προγράμματος για συνολικό αριθμό βημάτων της αλυσίδας (α) 500, (β) 1,000, (γ) 10,000, (δ) 100,000, (ε) 1,000,000, (στ) 10,000,000 και (ζ) 100,000,000. Πόσο μεταβάλεται η εκτίμηση ανάμεσα σε κάθε έξοδο; Τι παρατηρείτε σχετικά με το συνολικό χρόνο εκτέλεσης της προσομοίωσης ανάλογα με το συνολικό αριθμό βημάτων της αλυσίδας; Κατά τη γνώμη σας, ποια τιμή του συνολικού αριθμού των βημάτων της αλυσίδας επιτυγχάνει μια ικανοποιητική ισορροπία ανάμεσα στην ακρίβεια του αποτελέσματος και το συνολικό χρόνο εκτέλεσης της προσομοίωσης; <b>Για να τρέξετε το πρόγραμμα θα πρέπει να έχετε φορτώσει το αρχείο <i><a href="https://github.com/nkostopoulos/StochasticsLabPublic/blob/master/2020/lab3/simple_markov_chain_lib.py">simple_markov_chain_lib.py</a></i>.</b></li>

# %%
from __future__ import division
from simple_markov_chain_lib import markov_chain
import numpy as np
import matplotlib.pyplot as plt

def defineMarkovTable(): 
	markov_table = {
		0: {0: 0.6, 1: 0.2, 5: 0.2},
		1: {0: 0.2, 1: 0.6, 2: 0.2},
		2: {1: 0.2, 2: 0.6, 3: 0.2},
		3: {2: 0.2, 3: 0.6, 4: 0.2},
		4: {3: 0.2, 4: 0.6, 5: 0.2},
		5: {0: 0.2, 4: 0.2, 5: 0.6}
        }

	return markov_table

def defineInitDistribution():
	init_dist = {0: 1.}
	
	return init_dist

def calculateFrequencyTable(markov_table,init_dist,my_parameter):
	total_runs = my_parameter

	visits = list()
	visits = [0] * len(markov_table)

	for index in range(total_runs):
		mc.move()
		visits[mc.running_state] += 1
	
	frequency = [v/total_runs for v in visits]
	
	return frequency

def printFrequencies(frequency, markov_table):
	for state in range(0, len(markov_table)) :
		print(str(state) + ": ", str(frequency[state]))
	
	return None

def plotFrequencies(frequency):
	objects = ('1', '2', '3', '4', '5', '6')
	y_pos = np.arange(len(objects))
	
	plt.bar(y_pos, frequency, align='center', alpha=0.5)
	plt.xticks(y_pos, objects)
	plt.ylabel('States')
	plt.title('Frequencies')
	plt.show()
	
	return None

mylist = [500,1000,10000,100000,1000000,10000000,100000000]

for i in mylist:
    
    print("start for total_runs: ",i)
    print("\n")
    markov_table = defineMarkovTable()
    init_dist = defineInitDistribution()
    mc = markov_chain(markov_table, init_dist)
    mc.start()

    frequency = calculateFrequencyTable(markov_table, init_dist,i)
    printFrequencies(frequency, markov_table)
    plotFrequencies(frequency)
    
    print("\n finished for total_runs: ",i)
# Out:
# start for total_runs:  500
#
#
# 0:  0.194
# 1:  0.182
# 2:  0.17
# 3:  0.146
# 4:  0.134
# 5:  0.174
#  finished for total_runs:  500
# start for total_runs:  1000
#
#
# 0:  0.163
# 1:  0.178
# 2:  0.173
# 3:  0.201
# 4:  0.148
# 5:  0.137
#  finished for total_runs:  1000
# start for total_runs:  10000
#
#
# 0:  0.1561
# 1:  0.1634
# 2:  0.1817
# 3:  0.1761
# 4:  0.161
# 5:  0.1617
#  finished for total_runs:  10000
# start for total_runs:  100000
#
#
# 0:  0.16715
# 1:  0.1712
# 2:  0.16688
# 3:  0.16162
# 4:  0.16581
# 5:  0.16734
#  finished for total_runs:  100000
# start for total_runs:  1000000
#
#
# 0:  0.168089
# 1:  0.16733
# 2:  0.166948
# 3:  0.164676
# 4:  0.165641
# 5:  0.167316
#  finished for total_runs:  1000000
# start for total_runs:  10000000
#
#
# 0:  0.16666
# 1:  0.1669996
# 2:  0.1665338
# 3:  0.1664831
# 4:  0.1668137
# 5:  0.1665098
#  finished for total_runs:  10000000
# start for total_runs:  100000000
#
#
# 0:  0.16669043
# 1:  0.16664552
# 2:  0.16664702
# 3:  0.16661857
# 4:  0.16662683
# 5:  0.16677163
#  finished for total_runs:  100000000

# %% [markdown]
# Παρατηρούμε, πως όσο ανεβαίνει το total runs τόσο αυξάνει και η ταχύτητα του προγράμματος να εκτελεστεί. Ειδικά στην τιμή 1 000 0000 και 10 000 0000 που αργεί εμφανέστατα.
#
# Για total_runs περίπου 1000000 λαμβάνουμε ένα αρκετά ικανοποιητικό αποτέλεσμα σε αρκετά γρήγορο χρόνο, καθώς παρατηρούμε πως και να το τρέχαμε με total_runs = 100000000 τα αποτελέσματα δε θα άλλαζαν ιδιαίτερα.

# %% [markdown]
# <li>Τι παρατηρείτε σχετικά με τις τιμές της αναλλοίωτης κατανομής της παραπάνω μαρκοβιανής αλυσίδας; Να υπολογίσετε το άθροισμα των στοιχείων κάθε στήλης της μήτρας πιθανοτήτων <b>P</b>. Πώς ονομάζεται μία τέτοια μήτρα πιθανοτήτων και τι ισχύει για την αναλλοίωτη κατανομή μιας τέτοιας αλυσίδας;</li>

# %% [markdown]
# Παρατηρούμε πως οι τιμές της αναλλοίωτης κατανομής της παραπάνω μαρκοβιανής αλυσίδας είναι ίσες όσο αυξάνει η μεταβλητή total_runs.
#
# Mια μήτρα με άθροισμα στηλών στον πίνακα πιθανοτήτων __P__ 1 ονομάζεται διπλά στοχαστική μήτρα όπως αναφέραμε προηγουμένως.
#
# Για μια τέτοια αλυσίδα με διπλά στοχαστική μήτρα γνωρίζουμε πως έχουμε ίση πιθανότητα να βρεθούμε στην κάθε κατάσταση της αλυσίδας όταν έχει παρέλθει από μεταβατικό φαινόμενο. Επομένως για 6 καταστάσεις θα έχουμε τις εξής πιθανότητες π -> 1/6, 1/6 , 1/6 , 1/6 , 1/6 , 1/6
